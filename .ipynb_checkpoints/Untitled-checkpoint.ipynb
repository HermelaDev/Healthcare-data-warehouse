# %%
# etl/config.py
from sqlalchemy import create_engine

# ⚠️ Replace with your own passwords
PG_URI = "postgresql+psycopg2://postgres:DUMMY@localhost:5432/hospital_dw"
MYSQL_URI = "mysql+mysqlconnector://root:DUMMY@localhost:3306/hospital_source"

pg_engine = create_engine(PG_URI)
mysql_engine = create_engine(MYSQL_URI)
